# %%
# import modules
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 先ほど作った関数(fire_spread)を読むこむ

# %%
from wildfire import fire_spread

# %%
print(fire_spread(0.5, 5, 10))

# %% [markdown]
# ## グラフを描く
# x: 0から1まで20等分し、pとする<br>
# y: xに先ほどのfire_spreadを適用した結果の状態3の割合

# %%
x = np.linspace(0, 1, 20)
y = [fire_spread(v, 10, 100) for v in x]

# %%
fig, axes = plt.subplots()
axes.plot(x, y)
